# %% [markdown]
# <a href="https://colab.research.google.com/github/palanipsb/Python-Learning/blob/main/pandas_API_reference_workout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #Axes

# %%
df = pd.DataFrame({"AAA": [4, 5, 6, 7], "BBB": [10, 20, 30, 40], "CCC": [100, 50, -30, -50]})

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df.columns
# Out:
# Index(['AAA', 'BBB', 'CCC'], dtype='object')

# %%
df.dtypes
# Out:
# AAA    int64
# BBB    int64
# CCC    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AAA     4 non-null      int64
#  1   BBB     4 non-null      int64
#  2   CCC     4 non-null      int64
# dtypes: int64(3)
# memory usage: 224.0 bytes

# %%
df.select_dtypes(['int64'])
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df.values
# Out:
# array([[  4,  10, 100],
#        [  5,  20,  50],
#        [  6,  30, -30],
#        [  7,  40, -50]])

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1),
#  Index(['AAA', 'BBB', 'CCC'], dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 12

# %%
df.shape
# Out:
# (4, 3)

# %%
df.memory_usage()
# Out:
# Index    128
# AAA       32
# BBB       32
# CCC       32
# dtype: int64

# %%
df.empty
# Out:
# False

# %%
df.set_flags()
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %% [markdown]
# #Conversion

# %%
df.astype('int32')
# Out:
#    AAA  BBB  CCC
# 0    4   10  100
# 1    5   20   50
# 2    6   30  -30
# 3    7   40  -50

# %%
df.astype({'AAA':'float'})
# Out:
#    AAA  BBB  CCC
# 0  4.0   10  100
# 1  5.0   20   50
# 2  6.0   30  -30
# 3  7.0   40  -50

# %%
a = pd.DataFrame({'col1':[0,1],'col2':[3,4]})

# %%
a.astype({'col1':'category'})
# Out:
#   col1  col2
# 0    0     3
# 1    1     4

# %%
a.dtypes
# Out:
# col1    int64
# col2    int64
# dtype: object
