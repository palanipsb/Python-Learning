# %% [markdown]
# <a href="https://colab.research.google.com/github/palanipsb/Python-Learning/blob/main/Pandas_workout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pandas workout
import pandas as pd
import numpy  as np

# %%
s = pd.Series([1,2,3])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
dates = pd.date_range("20230101", periods=5)
dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
#df = pd.DataFrame(np.random.randn(5,5),index=dates, columns = list("ABCDE"))
df = pd.DataFrame(np.random.randn(5,5),index=dates,columns = list("ABCDE"))
df
# Out:
#                    A         B         C         D         E
# 2023-01-01 -1.192496  0.396636  0.256239  0.076516  0.123010
# 2023-01-02  2.023734  0.255297 -0.753514 -0.277196  1.027367
# 2023-01-03 -0.267614  0.140723  1.281322  0.107432 -0.612925
# 2023-01-04 -1.860353  0.203375  0.108630 -0.061345  0.219223
# 2023-01-05 -1.366042  1.837420  0.259398 -0.874249 -0.936443

# %%
df2 = pd.DataFrame(
     {
         "A": 1.0,
         "B": pd.Timestamp("20130102"),
         "C": pd.Series(1, index=list(range(4)), dtype="float32"),
         "D": np.array([3] * 4, dtype="int32"),
         "E": pd.Categorical(["test", "train", "test", "train"]),
         "F": "foo",
     }
 )

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2013-01-02  1.0  3   test  foo
# 1  1.0 2013-01-02  1.0  3  train  foo
# 2  1.0 2013-01-02  1.0  3   test  foo
# 3  1.0 2013-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D         E
# 2023-01-01 -1.192496  0.396636  0.256239  0.076516  0.123010
# 2023-01-02  2.023734  0.255297 -0.753514 -0.277196  1.027367
# 2023-01-03 -0.267614  0.140723  1.281322  0.107432 -0.612925
# 2023-01-04 -1.860353  0.203375  0.108630 -0.061345  0.219223
# 2023-01-05 -1.366042  1.837420  0.259398 -0.874249 -0.936443

# %%
df.tail()
# Out:
#                    A         B         C         D         E
# 2023-01-01 -1.192496  0.396636  0.256239  0.076516  0.123010
# 2023-01-02  2.023734  0.255297 -0.753514 -0.277196  1.027367
# 2023-01-03 -0.267614  0.140723  1.281322  0.107432 -0.612925
# 2023-01-04 -1.860353  0.203375  0.108630 -0.061345  0.219223
# 2023-01-05 -1.366042  1.837420  0.259398 -0.874249 -0.936443

# %%
df.index
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.to_numpy()
# Out:
# array([[-1.19249649,  0.39663562,  0.25623863,  0.07651644,  0.12301029],
#        [ 2.02373447,  0.25529741, -0.75351414, -0.2771959 ,  1.02736686],
#        [-0.26761397,  0.14072319,  1.28132232,  0.10743208, -0.61292466],
#        [-1.86035282,  0.20337469,  0.1086304 , -0.06134516,  0.2192229 ],
#        [-1.36604245,  1.83742024,  0.2593975 , -0.87424894, -0.93644317]])
